# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the data
# df = pd.read_csv(r"C:\Users\glotzie\Downloads\archive\electric_vehicles_spec_2025.csv.csv")
#
# df.head()

# %% [markdown]
# Each row represents one electric vehicle model.
# Each column describes one specification of the vehicle.

# %%
df.shape
# Out:
# (478, 22)

# %% [markdown]
# Expected Output (478, 22) There are
#
# 478 Electric Vehicles
#
# 22 Features

# %%
df.columns
# Out:
# Index(['brand', 'model', 'top_speed_kmh', 'battery_capacity_kWh',
#        'battery_type', 'number_of_cells', 'torque_nm', 'efficiency_wh_per_km',
#        'range_km', 'acceleration_0_100_s', 'fast_charging_power_kw_dc',
#        'fast_charge_port', 'towing_capacity_kg', 'cargo_volume_l', 'seats',
#        'drivetrain', 'segment', 'length_mm', 'width_mm', 'height_mm',
#        'car_body_type', 'source_url'],
#       dtype='object')

# %%
df.info()

numerical_columns = df.select_dtypes(include=np.number).columns
categorical_columns = df.select_dtypes(exclude=np.number).columns
print(numerical_columns)
print(categorical_columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
df.isnull().sum()
missing = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": df.isnull().mean()*100
})

missing
# Out:
#                            Missing Values  Percentage
# brand                                   0    0.000000
# model                                   1    0.209205
# top_speed_kmh                           0    0.000000
# battery_capacity_kWh                    0    0.000000
# battery_type                            0    0.000000
# number_of_cells                       202   42.259414
# torque_nm                               7    1.464435
# efficiency_wh_per_km                    0    0.000000
# range_km                                0    0.000000
# acceleration_0_100_s                    0    0.000000
# fast_charging_power_kw_dc               1    0.209205
# fast_charge_port                        1    0.209205
# towing_capacity_kg                     26    5.439331
# cargo_volume_l                          1    0.209205
# seats                                   0    0.000000
# drivetrain                              0    0.000000
# ...

# %%
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %%
df["range_km"].describe()
# Out:
# count    478.000000
# mean     393.179916
# std      103.287335
# min      135.000000
# 25%      320.000000
# 50%      397.500000
# 75%      470.000000
# max      685.000000
# Name: range_km, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["range_km"], bins=25)

plt.title("Distribution of EV Driving Range")

plt.show()
